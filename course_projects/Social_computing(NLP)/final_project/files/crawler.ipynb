# %%
import tweepy
from columnar import columnar
import json 
import pandas as pd

#First update below varibales with your own information
consumer_key = "ohiltOxhFTpbdUDtV6thRMLPX"
consumer_secret = "0ue4FsixVyktA39iFNs9mKEZrBpmc6OspbJvoej7JKF8jZDY9T"
access_token = "1489250229127770113-sPD6f998qjObWdGOZsKUUImbT66pwH"
access_token_secret = "6i5Beg9O4gGlnsP3Uxd0q3YJDeIvHmUChYbQMwxsKZ1AZ"


# Setting up Tweepy authorization
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# Define the search term and the date_since date

search_words = "#happyjenoday -filter:retweets"

# Collect tweets
tweets_2 = tweepy.Cursor(api.search_tweets,
                       q=search_words).items(10000)
tweets_list_2 = []
counter = 0
n_tweet= 0
for tweet in tweets_2:
    n_tweet+=1
    tweet_id=tweet.id
    tweet_ = api.get_status(tweet_id,tweet_mode="extended")
    #tweet_list = [tweet_.text, tweet_.favorite_count, tweet_.retweet_count]
    #print(tweet_list)
    #json_tweet = json.dumps(tweet_._json)
    with open('jeno_l.json', 'a') as f:
        json.dump(tweet_._json, f, indent=2)
    tweets_list_2.append([tweet_.id,tweet_.user.id,tweet_.coordinates,tweet_.geo,tweet_.lang, tweet_.created_at,tweet_.favorite_count,tweet_.retweet_count,tweet_.place, tweet.text])
    if counter <300: 
        word_list = tweet.text.split()
        number_of_words = len(word_list)
        if number_of_words> 5 :
            counter +=1
            with open('jeno_l_sample.json', 'a') as f:
                json.dump(tweet_._json, f, indent=2)
print(n_tweet)
# Pulling information from tweets iterable object
#tweets_list = [[tweet.id, tweet.created_at, tweet.text] for tweet in tweets]

#print tweets
headers = ['id','user id',"coordinates","geo","language", ' created_at','favorite_count','retweet_count','place','text']
#table = columnar(tweets_list, headers, no_borders=True)
df_2 = pd.DataFrame(tweets_list_2 , columns = headers)
# Out:
# Rate limit reached. Sleeping for: 593
# Rate limit reached. Sleeping for: 799
# Rate limit reached. Sleeping for: 813
# Rate limit reached. Sleeping for: 808
# Rate limit reached. Sleeping for: 733
# Rate limit reached. Sleeping for: 722
# Rate limit reached. Sleeping for: 712
# Rate limit reached. Sleeping for: 731
# Rate limit reached. Sleeping for: 712
# Rate limit reached. Sleeping for: 721
# Rate limit reached. Sleeping for: 718
# Rate limit reached. Sleeping for: 712
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /home/csrobot/.local/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     169             conn = connection.create_connection(
# --> 170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# /home/csrobot/.local/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# /usr/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /home/csrobot/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# /home/csrobot/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# /home/csrobot/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# /home/csrobot/.local/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# /home/csrobot/.local/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     181             raise NewConnectionError(
# --> 182                 self, "Failed to establish a new connection: %s" % e
#     183             )
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7efefaaa3a20>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /home/csrobot/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     449                     retries=self.max_retries,
# --> 450                     timeout=timeout
#     451                 )
#
# /home/csrobot/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     755             retries = retries.increment(
# --> 756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757             )
#
# /home/csrobot/.local/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/show.json?id=1517843285846654976&tweet_mode=extended (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7efefaaa3a20>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /home/csrobot/.local/lib/python3.6/site-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     218                         data=post_data, files=files, json=json_payload,
# --> 219                         timeout=self.timeout, auth=auth, proxies=self.proxy
#     220                     )
#
# /home/csrobot/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#
# /home/csrobot/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#
# /home/csrobot/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     518
# --> 519             raise ConnectionError(e, request=request)
#     520
#
# ConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/show.json?id=1517843285846654976&tweet_mode=extended (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7efefaaa3a20>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))
#
# During handling of the above exception, another exception occurred:
#
# TweepyException                           Traceback (most recent call last)
# <ipython-input-3-c6885fbd8718> in <module>()
#      12     n_tweet+=1
#      13     tweet_id=tweet.id
# ---> 14     tweet_ = api.get_status(tweet_id,tweet_mode="extended")
#      15     #tweet_list = [tweet_.text, tweet_.favorite_count, tweet_.retweet_count]
#      16     #print(tweet_list)
#
# /home/csrobot/.local/lib/python3.6/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# /home/csrobot/.local/lib/python3.6/site-packages/tweepy/api.py in get_status(self, id, **kwargs)
#     883                 'id', 'trim_user', 'include_my_retweet', 'include_entities',
#     884                 'include_ext_alt_text', 'include_card_uri'
# --> 885             ), id=id, **kwargs
#     886         )
#     887
#
# /home/csrobot/.local/lib/python3.6/site-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     220                     )
#     221                 except Exception as e:
# --> 222                     raise TweepyException(f'Failed to send request: {e}').with_traceback(sys.exc_info()[2])
#     223
#     224                 if 200 <= resp.status_code < 300:
#
# /home/csrobot/.local/lib/python3.6/site-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     217                         method, url, params=params, headers=headers,
#     218                         data=post_data, files=files, json=json_payload,
# --> 219                         timeout=self.timeout, auth=auth, proxies=self.proxy
#     220                     )
#     221                 except Exception as e:
#
# /home/csrobot/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# /home/csrobot/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# /home/csrobot/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     517                 raise SSLError(e, request=request)
#     518
# --> 519             raise ConnectionError(e, request=request)
#     520
#     521         except ClosedPoolError as e:
#
# TweepyException: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/show.json?id=1517843285846654976&tweet_mode=extended (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7efefaaa3a20>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))

# %%
# Define the search term and the date_since date

search_words = "#رمضان OR #ramadan -filter:retweets"

# Collect tweets
tweets_1 = tweepy.Cursor(api.search_tweets,
                       q=search_words).items(10000)
tweets_list_1 = []
counter = 0
n_tweet= 0
for tweet in tweets_1:
    n_tweet+=1
    tweet_id=tweet.id
    tweet_ = api.get_status(tweet_id,tweet_mode="extended")
    #tweet_list = [tweet_.text, tweet_.favorite_count, tweet_.retweet_count]
    #print(tweet_list)
    #json_tweet = json.dumps(tweet_._json)
    with open('ramadan_l.json', 'a') as f:
        json.dump(tweet_._json, f, indent=2)
    tweets_list_1.append([tweet_.id,tweet_.user.id,tweet_.user.location,tweet_.coordinates,tweet_.geo,tweet_.lang, tweet_.created_at,tweet_.favorite_count,tweet_.retweet_count,tweet_.place, tweet.text])
    if counter <300: 
        word_list = tweet.text.split()
        number_of_words = len(word_list)
        if number_of_words> 5 :
            counter +=1
            with open('ramadan_l_sample.json', 'a') as f:
                json.dump(tweet_._json, f, indent=2)
print(n_tweet)
# Pulling information from tweets iterable object
#tweets_list = [[tweet.id, tweet.created_at, tweet.text] for tweet in tweets]

#print tweets
headers = ['id','user id',"location","coordinates","geo","language", ' created_at','favorite_count','retweet_count','place','text']
#table = columnar(tweets_list, headers, no_borders=True)
df_1 = pd.DataFrame(tweets_list_1 , columns = headers)
# Out:
# Rate limit reached. Sleeping for: 506
# Rate limit reached. Sleeping for: 806
# Rate limit reached. Sleeping for: 814
# Rate limit reached. Sleeping for: 811
# Rate limit reached. Sleeping for: 813
# Rate limit reached. Sleeping for: 814
# Rate limit reached. Sleeping for: 813
# Rate limit reached. Sleeping for: 812
# Rate limit reached. Sleeping for: 818
# Rate limit reached. Sleeping for: 814
# Rate limit reached. Sleeping for: 811
# Rate limit reached. Sleeping for: 810
# Rate limit reached. Sleeping for: 813
# Rate limit reached. Sleeping for: 819
# Rate limit reached. Sleeping for: 816
# Rate limit reached. Sleeping for: 816
# Rate limit reached. Sleeping for: 814
# Rate limit reached. Sleeping for: 812
# Rate limit reached. Sleeping for: 816
# Rate limit reached. Sleeping for: 812
# Rate limit reached. Sleeping for: 817
# Rate limit reached. Sleeping for: 815
# 10000
